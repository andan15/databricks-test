# %% [markdown]
# ## Mount s3 buckets

# %%
dbutils.fs.ls("s3a://mtg-da-dev/tonja/mtgapi-recommendation/")
dbutils.fs.mount("s3a://mtg-da-dev/tonja/mtgapi-recommendation/","/mnt/tonja/mtgapi-recommendation" )
dbutils.fs.ls("s3a://mtg-da-dev/tonja/similartitles-program-feed/", "/mnt/tonja/similartitles-program-feed")

# %%
display(dbutils.fs.ls("dbfs:/mnt/tonja/similartitles-program-feed"))
display(dbutils.fs.ls("dbfs:/mnt/tonja/mtgapi-recommendation"))

# %%
# %sh
ls /dbfs/mnt/tonja/mtgapi-recommendation/Prod/input-viewing-data-iq/2018/07/25/00

# %% [markdown]
# ##Put data to s3

# %%
dbutils.fs.ls("s3a://mtg-da-dev/databricks-output")
dbutils.fs.mount("s3a://mtg-da-dev/databricks-output/","/mnt/mtg-da-dev/databricks-output" )

# %%
# %sh
ls /dbfs/mnt/mtg-da-dev/databricks-output

# %%
# %sh
mkdir /dbfs/mnt/mtg-da-dev/databricks-output/createTestFolder
